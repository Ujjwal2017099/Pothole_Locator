# %%
# %cd /content/drive/MyDrive/Pothole
# !git clone https://github.com/WongKinYiu/yolov7.git
# Out:
# /content/drive/MyDrive/Pothole

# %%
# %cd yolov7
# Out:
# /content/drive/MyDrive/Pothole/yolov7

# %%
# !pip install -r requirements.txt

# %%
# !mkdir train_data
# !mkdir train_data/images
# !mkdir train_data/labels

# %%
# !unzip /content/drive/MyDrive/Pothole/train20175_fold-label.zip -d /content/drive/MyDrive/Pothole/yolov7/train_data/labels

# %%
# !wget https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7_training.pt
# !wget https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7x_training.pt

# %%
import torch
import gc
torch.cuda.empty_cache()

# %%
fold = 5
cmd = f'python train.py --workers 8 --device 0 --batch-size 16 --epochs 40 --data wheat{fold}.yaml --img 640 640 --cfg cfg/training/yolov7-custom.yaml --weights yolov7_training.pt --name yolov7-custom --hyp data/hyp.scratch.custom.yaml'

# %%
# weights : yolov7_training.pt
try:
  # !{cmd}
except:
  print("Failed")

gc.collect()
torch.cuda.empty_cache()
# Out:
# 2024-01-19 05:21:50.576903: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-19 05:21:50.576953: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-19 05:21:50.578362: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-19 05:21:50.585801: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# ## YOLOV7X-TRAINING

# %%
fold = 5
cmd = f'python train.py --workers 8 --device 0 --batch-size 16 --epochs 40 --data wheat{fold}.yaml --img 640 640 --cfg cfg/training/yolov7x-custom.yaml --weights yolov7x_training.pt --name yolov7x-custom --hyp data/hyp.scratch.custom.yaml'

# %%
# weights : yolov7x_training.pt
try:
  # !{cmd}
except:
  print("Failed")

gc.collect()
torch.cuda.empty_cache()
# Out:
# 2024-01-18 16:23:28.197930: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-18 16:23:28.197980: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-18 16:23:28.199474: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-18 16:23:28.207943: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
